# %%
#WhatsApp Chat with Unofficial KIIT

import re
import pandas as pd

# %%
f = open('./chats/WhatsApp Chat with Unofficial KIIT.txt','r',encoding='utf-8')

# %%
data = f.read()

# %%
print(data)
# Out:
# 05/08/2023, 11:01 am - Messages and calls are end-to-end encrypted. No one outside of this chat, not even WhatsApp, can read or listen to them. Tap to learn more.
# 05/08/2023, 10:41 am - ~ Nitin Kumar 😉 created group "Unofficial Deolitte "
# 05/08/2023, 11:01 am - You joined using this group's invite link
# 05/08/2023, 11:01 am - +91 87098 77032 joined using this group's invite link
# 05/08/2023, 11:01 am - +91 72559 25971 joined using this group's invite link
# 05/08/2023, 11:01 am - +91 87973 36741 joined using this group's invite link
# 05/08/2023, 11:02 am - +91 77820 37428 joined using this group's invite link
# 05/08/2023, 11:02 am - +91 78479 47733 joined using this group's invite link
# 05/08/2023, 11:02 am - +91 85217 99855 joined using this group's invite link
# 05/08/2023, 11:02 am - +91 93341 12493 joined using this group's invite link
# 05/08/2023, 11:02 am - +91 70088 12348 joined using this group's invite link
# ...

# %%
pattern='\d{2}/\d{2}/\d{4}, \d{2}:\d{2} [ap]m'

# %%
messages = re.split(pattern,data)[1:]
messages
# Out:
# []

# %%
dates = re.findall(pattern,data)
dates
# Out:
# ['05/08/2023, 11:01\u202fam - ',
#  '05/08/2023, 10:41\u202fam - ',
#  '05/08/2023, 11:01\u202fam - ',
#  '05/08/2023, 11:01\u202fam - ',
#  '05/08/2023, 11:01\u202fam - ',
#  '05/08/2023, 11:01\u202fam - ',
#  '05/08/2023, 11:02\u202fam - ',
#  '05/08/2023, 11:02\u202fam - ',
#  '05/08/2023, 11:02\u202fam - ',
#  '05/08/2023, 11:02\u202fam - ',
#  '05/08/2023, 11:02\u202fam - ',
#  '05/08/2023, 11:02\u202fam - ',
#  '05/08/2023, 11:02\u202fam - ',
#  '05/08/2023, 11:02\u202fam - ',
#  '05/08/2023, 11:02\u202fam - ',
#  '05/08/2023, 11:02\u202fam - ',
#  '05/08/2023, 11:02\u202fam - ',
#  '05/08/2023, 11:03\u202fam - ',
#  '05/08/2023, 11:03\u202fam - ',
#  '05/08/2023, 11:03\u202fam - ',
#  '05/08/2023, 11:03\u202fam - ',
#  '05/08/2023, 11:03\u202fam - ',
#  '05/08/2023, 11:03\u202fam - ',
#  '05/08/2023, 11:03\u202fam - ',
#  '05/08/2023, 11:03\u202fam - ',
#  '05/08/2023, 11:03\u202fam - ',
#  '05/08/2023, 11:03\u202fam - ',
#  '05/08/2023, 11:03\u202fam - ',
# ...
